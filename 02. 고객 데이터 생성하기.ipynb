# %% [markdown]
# # 1. 회원정보 데이터 전처리

# %%
import pandas as pd

# %%
cust_info = pd.read_csv('/content/drive/MyDrive/CARD-LANGCHAIN/data/201807_회원정보.csv')

# %%
cust_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 79 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   기준년월                int64
#  1   발급회원번호              object
#  2   남녀구분코드              int64
#  3   연령                  object
#  4   VIP등급코드             object
#  5   최상위카드등급코드           object
#  6   회원여부_이용가능           int64
#  7   회원여부_이용가능_CA        int64
#  8   회원여부_이용가능_카드론       int64
#  9   소지여부_신용             int64
#  10  소지카드수_유효_신용         int64
#  11  소지카드수_이용가능_신용       int64
#  12  입회일자_신용             int64
#  13  입회경과개월수_신용          int64
#  14  회원여부_연체             int64
#  15  이용거절여부_카드론          int64
#  16  동의여부_한도증액안내         int64
#  17  수신거부여부_TM           int64
#  18  수신거부여부_DM           int64
#  19  수신거부여부_메일           int64
#  20  수신거부여부_SMS          int64
#  21  가입통신회사코드            object
#  22  탈회횟수_누적             int64
#  23  최종탈회후경과월            int64
# ...

# %%
cust_df = cust_info[['발급회원번호'
,'남녀구분코드'
,'연령'
,'Life_Stage']]
cust_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   발급회원번호      object
#  1   남녀구분코드      int64
#  2   연령          object
#  3   Life_Stage  object
# dtypes: int64(1), object(3)
# memory usage: 91.6+ MB

# %%
cust_df.head()
# Out:
#   발급회원번호  남녀구분코드   연령  Life_Stage
# 0  SYN_0       2  40대  5.자녀성장기(2)
# 1  SYN_1       1  30대  4.자녀성장기(1)
# 2  SYN_2       2  40대  4.자녀성장기(1)
# 3  SYN_3       1  40대  4.자녀성장기(1)
# 4  SYN_4       2  40대  5.자녀성장기(2)

# %%
cust_df.to_csv('회원정보.csv',index=False)

# %% [markdown]
# # 2. 결제 데이터 전처리

# %%
payment = pd.read_csv('/content/drive/MyDrive/CARD-LANGCHAIN/data/201807_승인매출정보.csv')
payment.head()
# Out:
#      기준년월 발급회원번호  최종이용일자_기본  최종이용일자_신판  최종이용일자_CA  최종이용일자_카드론  최종이용일자_체크  \
# 0  201807  SYN_0   20180719   20180713   20180719       10101   20180203
# 1  201807  SYN_1   20180719   20180719   20170728    20170327      10101
# 2  201807  SYN_2   20150731   20150731      10101       10101      10101
# 3  201807  SYN_3   20180728   20180728   20130201       10101      10101
# 4  201807  SYN_4   20171111   20171111      10101       10101      10101
#
#    최종이용일자_일시불  최종이용일자_할부  이용건수_신용_B0M  ...  승인거절건수_한도초과_B0M  승인거절건수_BL_B0M  \
# 0    20180709   20180713           11  ...                0              0
# 1    20180719   20171231           13  ...                0              0
# 2    20150731      10101           -3  ...                0              0
# 3    20180728   20140531            5  ...                0              0
# 4    20171111   20170501           -1  ...                0              0
#
# ...

# %%
payment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Columns: 430 entries, 기준년월 to 이용금액대
# dtypes: float64(3), int64(409), object(18)
# memory usage: 9.6+ GB

# %%
df_payment= payment[['발급회원번호', '이용금액_쇼핑',
'이용금액_요식',
'이용금액_교통',
'이용금액_의료',
'이용금액_납부',
'이용금액_교육',
'이용금액_여유생활',
'이용금액_사교활동',
'이용금액_일상생활',
'이용금액_해외',
'쇼핑_도소매_이용금액'
,'쇼핑_백화점_이용금액'
,'쇼핑_마트_이용금액'
,'쇼핑_슈퍼마켓_이용금액'
,'쇼핑_편의점_이용금액'
,'쇼핑_아울렛_이용금액'
,'쇼핑_온라인_이용금액'
,'쇼핑_기타_이용금액'
,'쇼핑_전체_이용금액'
,'교통_주유이용금액'
,'교통_정비이용금액'
,'교통_통행료이용금액'
,'교통_버스지하철이용금액'
,'교통_택시이용금액'
,'교통_철도버스이용금액'
,'교통_전체이용금액'
,'여유_운동이용금액'
,'여유_Pet이용금액'
,'여유_공연이용금액'
,'여유_공원이용금액'
,'여유_숙박이용금액'
,'여유_여행이용금액'
,'여유_항공이용금액'
,'여유_기타이용금액'
,'여유_전체이용금액'
,'납부_통신비이용금액'
,'납부_관리비이용금액'
,'납부_렌탈료이용금액'
,'납부_가스전기료이용금액'
,'납부_보험료이용금액'
,'납부_유선방송이용금액'
,'납부_건강연금이용금액'
,'납부_기타이용금액'
,'납부_전체이용금액']]

# %%
df_payment.to_csv('결제데이터.csv', index=False)

# %%
df_payment.tail(20)
# Out:
#               발급회원번호  이용금액_쇼핑  이용금액_요식  이용금액_교통  이용금액_의료  이용금액_납부  이용금액_교육  \
# 2999980  SYN_2999980    21379        0        0        0   110212        0
# 2999981  SYN_2999981        0        0        0        0        0        0
# 2999982  SYN_2999982  1227210   158430   280829        0   152818    28391
# 2999983  SYN_2999983        0        0        0        0        0        0
# 2999984  SYN_2999984   297495        0    36043        0   486528        0
# 2999985  SYN_2999985   104706    88008   206013        0        0        0
# 2999986  SYN_2999986        0        0        0        0   224913  1055072
# 2999987  SYN_2999987        0        0    51704   350161   252869        0
# 2999988  SYN_2999988    60031        0        0        0   117174        0
# 2999989  SYN_2999989        0        0        0        0        0        0
# 2999990  SYN_2999990   686405    35147   241756    91469        0        0
# ...
